# %%
# %load_ext autoreload
# %autoreload 2

# %%
from datasets import Dataset, DatasetDict
import numpy as np
import pandas as pd
# import torch
from transformers import (AutoTokenizer, AutoModelForSequenceClassification)
from transformers import BertForSequenceClassification  # Check

# %% [markdown]
# # Import tokenizer, model

# %%
max_seq_length = 128

# %%
tokenizer_name = "bert-base-cased"

# %%
tokenizer = AutoTokenizer.from_pretrained(tokenizer_name)
def preprocess_text(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True, max_length=max_seq_length)

# %%
model_name = "g8a9/bert-base-cased_ami18"

# %%
model = AutoModelForSequenceClassification.from_pretrained(model_name).eval()
effective_model = BertForSequenceClassification.from_pretrained(model_name).eval()

# %% [markdown]
# # nlxplain

# %%
from nlxplain import Explainer

# %%
exp = Explainer(model, tokenizer)

# %%
text = "You are a woman"
exp.classify(text)
print(f"Importance occlusion:\n {exp.compute_occlusion_importance(text).numpy()}")
exp.compute_table(text, target = 1)
# Out:
# IDX: You are a woman
# Text: You are a woman
# Probabilities: tensor([[0.2007, 0.7993]])
# Prediction: 1
# Importance occlusion:
#  [-0.01087821  0.00281805  0.01252252 -0.51788306]
# tokens       You       are         a     woman
# G       0.159478  0.163659  0.117216  0.341822
# GxI    -0.201490  0.308628 -0.051436 -0.271019
# IG      0.306092  0.341990  0.082422 -0.269495
# SHAP    0.041938 -0.097407 -0.067262  0.793392
# LIME    0.191277 -0.070717  0.269628  0.290803

# %% [markdown]
# # Evaluate explanations

# %%
text = "You are a woman"
explanations = exp.compute_table(text, target = exp.get_predicted_label(text))
tokens = list(explanations.columns)
soft_score_explanation = explanations.loc["SHAP"].values
print(soft_score_explanation)
import seaborn as sns
palette = sns.diverging_palette(240, 10, as_cmap=True)
explanations.style.background_gradient(axis=1, cmap=palette, vmin=-1, vmax=1)
# Out:
# [ 0.04193844 -0.09740739 -0.06726249  0.79339168]
# <style type="text/css">
# #T_70d1e_row0_col0, #T_70d1e_row0_col1 {
#   background-color: #efd4d6;
#   color: #000000;
# }
# #T_70d1e_row0_col2 {
#   background-color: #efdbdd;
#   color: #000000;
# }
# #T_70d1e_row0_col3, #T_70d1e_row2_col1 {
#   background-color: #eab3b7;
#   color: #000000;
# }
# #T_70d1e_row1_col0 {
#   background-color: #cedae4;
#   color: #000000;
# }
# #T_70d1e_row1_col1, #T_70d1e_row2_col0 {
#   background-color: #ebb9bd;
#   color: #000000;
# }
# #T_70d1e_row1_col2 {
#   background-color: #e8ecef;
#   color: #000000;
# }
# #T_70d1e_row1_col3, #T_70d1e_row2_col3 {
#   background-color: #c2d2df;
#   color: #000000;
# }
# #T_70d1e_row2_col2 {
#   background-color: #f0e3e3;
#   color: #000000;
# }
# #T_70d1e_row3_col0 {
#   background-color: #f1eaea;
#   color: #000000;
# }
# #T_70d1e_row3_col1 {
#   background-color: #e0e6eb;
#   color: #000000;
# }
# #T_70d1e_row3_col2 {
#   background-color: #e5eaee;
#   color: #000000;
# }
# #T_70d1e_row3_col3 {
#   background-color: #df6069;
#   color: #f1f1f1;
# }
# #T_70d1e_row4_col0 {
#   background-color: #eecfd1;
#   color: #000000;
# }
# #T_70d1e_row4_col1 {
#   background-color: #e4e9ed;
#   color: #000000;
# }
# #T_70d1e_row4_col2 {
#   background-color: #ecc0c3;
#   color: #000000;
# }
# #T_70d1e_row4_col3 {
#   background-color: #ebbcbf;
#   color: #000000;
# }
# </style>
# <table id="T_70d1e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >tokens</th>
#       <th id="T_70d1e_level0_col0" class="col_heading level0 col0" >You</th>
#       <th id="T_70d1e_level0_col1" class="col_heading level0 col1" >are</th>
#       <th id="T_70d1e_level0_col2" class="col_heading level0 col2" >a</th>
#       <th id="T_70d1e_level0_col3" class="col_heading level0 col3" >woman</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70d1e_level0_row0" class="row_heading level0 row0" >G</th>
#       <td id="T_70d1e_row0_col0" class="data row0 col0" >0.159478</td>
#       <td id="T_70d1e_row0_col1" class="data row0 col1" >0.163659</td>
#       <td id="T_70d1e_row0_col2" class="data row0 col2" >0.117216</td>
#       <td id="T_70d1e_row0_col3" class="data row0 col3" >0.341822</td>
#     </tr>
#     <tr>
#       <th id="T_70d1e_level0_row1" class="row_heading level0 row1" >GxI</th>
#       <td id="T_70d1e_row1_col0" class="data row1 col0" >-0.201490</td>
#       <td id="T_70d1e_row1_col1" class="data row1 col1" >0.308628</td>
#       <td id="T_70d1e_row1_col2" class="data row1 col2" >-0.051436</td>
#       <td id="T_70d1e_row1_col3" class="data row1 col3" >-0.271019</td>
#     </tr>
#     <tr>
#       <th id="T_70d1e_level0_row2" class="row_heading level0 row2" >IG</th>
#       <td id="T_70d1e_row2_col0" class="data row2 col0" >0.306092</td>
#       <td id="T_70d1e_row2_col1" class="data row2 col1" >0.341990</td>
#       <td id="T_70d1e_row2_col2" class="data row2 col2" >0.082422</td>
#       <td id="T_70d1e_row2_col3" class="data row2 col3" >-0.269495</td>
#     </tr>
#     <tr>
#       <th id="T_70d1e_level0_row3" class="row_heading level0 row3" >SHAP</th>
#       <td id="T_70d1e_row3_col0" class="data row3 col0" >0.041938</td>
#       <td id="T_70d1e_row3_col1" class="data row3 col1" >-0.097407</td>
#       <td id="T_70d1e_row3_col2" class="data row3 col2" >-0.067262</td>
#       <td id="T_70d1e_row3_col3" class="data row3 col3" >0.793392</td>
#     </tr>
#     <tr>
#       <th id="T_70d1e_level0_row4" class="row_heading level0 row4" >LIME</th>
#       <td id="T_70d1e_row4_col0" class="data row4 col0" >0.191277</td>
#       <td id="T_70d1e_row4_col1" class="data row4 col1" >-0.070717</td>
#       <td id="T_70d1e_row4_col2" class="data row4 col2" >0.269628</td>
#       <td id="T_70d1e_row4_col3" class="data row4 col3" >0.290803</td>
#     </tr>
#   </tbody>
# </table>

# %%
from nlxplain import Evalutator

evalt = Evalutator(exp)
thresholds = [1, 2, 3, 4]
soft_score_explanation = explanations.loc["SHAP"].values
c = evalt.compute_comprehensiveness_ths(text, soft_score_explanation, thresholds, based_on = "k")
s = evalt.compute_sufficiency_ths(text, soft_score_explanation, thresholds, based_on = "k")

# Temporary form
print(c)
print(s)
# Out:
# {1: ([3], 0.5178830623626709), 2: ([3, 0], 0.6923361420631409)}
# {1: ([3], -0.013836026191711426), 2: ([3, 0], -0.02977198362350464)}

# %% [markdown]
# Compute the
# - **taud_loo**: kendall tau distance between the explanation scores and the occlusion importance (leave one out)
# - **AOPC comprehensiveness** (ERASER) -> area under the perturbation curve of the comprehensiveness
# - **AOPC sufficiency** (ERASER) -> area under the perturbation curve of the sufficiency
#
#
# Comprehensiveness: f(x) - f(x\r) where r is the rationale, the important tokens of the explanation. The higher the better
#
# Sufficiency: f(x) - f(r). Close to 0 is better.
#
#
# For each measure, we also provide the ranking among the explainers.

# %% [markdown]
# In the following, we consider the following approaches to extract the "rationale", the most important tokens:
#
# - top k: based_on = "k"   --> take only the top k elements, varying k.
# - percentage: take top 1%, 5%, 10%, 20% and 50% of tokens as in ERASER, 0, 10, 20, ..., 100% as in Atanasova
# - threshold: take elements greater than a threshold.

# %% [markdown]
# ## Top k (positive)

# %%
thresholds = [1,2,3,4]
df_eval, style_df = evalt.evaluate_explainers(text, explanations, thresholds, based_on = "k", only_pos = True)
style_df
# Out:
# <style type="text/css">
# #T_bd3b5_row0_col0, #T_bd3b5_row0_col1 {
#   background-color: #efd4d6;
#   color: #000000;
# }
# #T_bd3b5_row0_col2 {
#   background-color: #efdbdd;
#   color: #000000;
# }
# #T_bd3b5_row0_col3, #T_bd3b5_row2_col1 {
#   background-color: #eab3b7;
#   color: #000000;
# }
# #T_bd3b5_row0_col4 {
#   background-color: #e79ba1;
#   color: #000000;
#   background-color: #c5b3ec;
#   color: #000000;
# }
# #T_bd3b5_row0_col5, #T_bd3b5_row0_col7, #T_bd3b5_row2_col9 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #cee5ec;
#   color: #000000;
# }
# #T_bd3b5_row0_col6 {
#   background-color: #f1f1f2;
#   color: #000000;
#   background-color: #7878f9;
#   color: #f1f1f1;
# }
# #T_bd3b5_row0_col8, #T_bd3b5_row3_col8 {
#   background-color: #eed3d5;
#   color: #000000;
#   background-color: #8c8cf8;
#   color: #f1f1f1;
# }
# #T_bd3b5_row0_col9, #T_bd3b5_row3_col5, #T_bd3b5_row3_col7, #T_bd3b5_row3_col9 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #add8e6;
#   color: #000000;
# }
# #T_bd3b5_row1_col0 {
#   background-color: #cedae4;
#   color: #000000;
# }
# #T_bd3b5_row1_col1, #T_bd3b5_row2_col0 {
#   background-color: #ebb9bd;
#   color: #000000;
# }
# #T_bd3b5_row1_col2 {
#   background-color: #e8ecef;
#   color: #000000;
# }
# #T_bd3b5_row1_col3, #T_bd3b5_row2_col3 {
#   background-color: #c2d2df;
#   color: #000000;
# }
# #T_bd3b5_row1_col4, #T_bd3b5_row2_col4 {
#   background-color: #f1f1f2;
#   color: #000000;
#   background-color: #eff2f0;
#   color: #000000;
# }
# #T_bd3b5_row1_col5, #T_bd3b5_row1_col9, #T_bd3b5_row2_col7 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #dfebef;
#   color: #000000;
# }
# #T_bd3b5_row1_col6 {
#   background-color: #e17179;
#   color: #f1f1f1;
#   background-color: #cdcdf5;
#   color: #000000;
# }
# #T_bd3b5_row1_col7, #T_bd3b5_row2_col5 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #eff1f2;
#   color: #000000;
# }
# #T_bd3b5_row1_col8 {
#   background-color: #de5963;
#   color: #f1f1f1;
#   background-color: #ddddf4;
#   color: #000000;
# }
# #T_bd3b5_row2_col2 {
#   background-color: #f0e3e3;
#   color: #000000;
# }
# #T_bd3b5_row2_col6 {
#   background-color: #e37e85;
#   color: #f1f1f1;
#   background-color: #c4c4f5;
#   color: #000000;
# }
# #T_bd3b5_row2_col8 {
#   background-color: #e2777f;
#   color: #f1f1f1;
#   background-color: #c9c9f5;
#   color: #000000;
# }
# #T_bd3b5_row3_col0 {
#   background-color: #f1eaea;
#   color: #000000;
# }
# #T_bd3b5_row3_col1 {
#   background-color: #e0e6eb;
#   color: #000000;
# }
# #T_bd3b5_row3_col2 {
#   background-color: #e5eaee;
#   color: #000000;
# }
# #T_bd3b5_row3_col3 {
#   background-color: #df6069;
#   color: #f1f1f1;
# }
# #T_bd3b5_row3_col4 {
#   background-color: #e38289;
#   color: #f1f1f1;
#   background-color: #b8a1eb;
#   color: #000000;
# }
# #T_bd3b5_row3_col6 {
#   background-color: #edeff1;
#   color: #000000;
#   background-color: #7676f9;
#   color: #f1f1f1;
# }
# #T_bd3b5_row4_col0 {
#   background-color: #eecfd1;
#   color: #000000;
# }
# #T_bd3b5_row4_col1 {
#   background-color: #e4e9ed;
#   color: #000000;
# }
# #T_bd3b5_row4_col2 {
#   background-color: #ecc0c3;
#   color: #000000;
# }
# #T_bd3b5_row4_col3 {
#   background-color: #ebbcbf;
#   color: #000000;
# }
# #T_bd3b5_row4_col4 {
#   background-color: #e4858c;
#   color: #f1f1f1;
#   background-color: #b9a3eb;
#   color: #000000;
# }
# #T_bd3b5_row4_col5, #T_bd3b5_row4_col7, #T_bd3b5_row4_col9 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #bedee9;
#   color: #000000;
# }
# #T_bd3b5_row4_col6 {
#   background-color: #eff0f2;
#   color: #000000;
#   background-color: #7777f9;
#   color: #f1f1f1;
# }
# #T_bd3b5_row4_col8 {
#   background-color: #eab5b9;
#   color: #000000;
#   background-color: #a0a0f7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bd3b5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >tokens</th>
#       <th id="T_bd3b5_level0_col0" class="col_heading level0 col0" >You</th>
#       <th id="T_bd3b5_level0_col1" class="col_heading level0 col1" >are</th>
#       <th id="T_bd3b5_level0_col2" class="col_heading level0 col2" >a</th>
#       <th id="T_bd3b5_level0_col3" class="col_heading level0 col3" >woman</th>
#       <th id="T_bd3b5_level0_col4" class="col_heading level0 col4" >aopc_compr</th>
#       <th id="T_bd3b5_level0_col5" class="col_heading level0 col5" >aopc_compr_r</th>
#       <th id="T_bd3b5_level0_col6" class="col_heading level0 col6" >aopc_suff</th>
#       <th id="T_bd3b5_level0_col7" class="col_heading level0 col7" >aopc_suff_r</th>
#       <th id="T_bd3b5_level0_col8" class="col_heading level0 col8" >taud_loo</th>
#       <th id="T_bd3b5_level0_col9" class="col_heading level0 col9" >taud_loo_r</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd3b5_level0_row0" class="row_heading level0 row0" >G</th>
#       <td id="T_bd3b5_row0_col0" class="data row0 col0" >0.159478</td>
#       <td id="T_bd3b5_row0_col1" class="data row0 col1" >0.163659</td>
#       <td id="T_bd3b5_row0_col2" class="data row0 col2" >0.117216</td>
#       <td id="T_bd3b5_row0_col3" class="data row0 col3" >0.341822</td>
#       <td id="T_bd3b5_row0_col4" class="data row0 col4" >0.472835</td>
#       <td id="T_bd3b5_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_bd3b5_row0_col6" class="data row0 col6" >-0.005580</td>
#       <td id="T_bd3b5_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_bd3b5_row0_col8" class="data row0 col8" >0.166667</td>
#       <td id="T_bd3b5_row0_col9" class="data row0 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bd3b5_level0_row1" class="row_heading level0 row1" >GxI</th>
#       <td id="T_bd3b5_row1_col0" class="data row1 col0" >-0.201490</td>
#       <td id="T_bd3b5_row1_col1" class="data row1 col1" >0.308628</td>
#       <td id="T_bd3b5_row1_col2" class="data row1 col2" >-0.051436</td>
#       <td id="T_bd3b5_row1_col3" class="data row1 col3" >-0.271019</td>
#       <td id="T_bd3b5_row1_col4" class="data row1 col4" >-0.002818</td>
#       <td id="T_bd3b5_row1_col5" class="data row1 col5" >4</td>
#       <td id="T_bd3b5_row1_col6" class="data row1 col6" >0.701342</td>
#       <td id="T_bd3b5_row1_col7" class="data row1 col7" >5</td>
#       <td id="T_bd3b5_row1_col8" class="data row1 col8" >0.833333</td>
#       <td id="T_bd3b5_row1_col9" class="data row1 col9" >4</td>
#     </tr>
#     <tr>
#       <th id="T_bd3b5_level0_row2" class="row_heading level0 row2" >IG</th>
#       <td id="T_bd3b5_row2_col0" class="data row2 col0" >0.306092</td>
#       <td id="T_bd3b5_row2_col1" class="data row2 col1" >0.341990</td>
#       <td id="T_bd3b5_row2_col2" class="data row2 col2" >0.082422</td>
#       <td id="T_bd3b5_row2_col3" class="data row2 col3" >-0.269495</td>
#       <td id="T_bd3b5_row2_col4" class="data row2 col4" >-0.003000</td>
#       <td id="T_bd3b5_row2_col5" class="data row2 col5" >5</td>
#       <td id="T_bd3b5_row2_col6" class="data row2 col6" >0.627134</td>
#       <td id="T_bd3b5_row2_col7" class="data row2 col7" >4</td>
#       <td id="T_bd3b5_row2_col8" class="data row2 col8" >0.666667</td>
#       <td id="T_bd3b5_row2_col9" class="data row2 col9" >3</td>
#     </tr>
#     <tr>
#       <th id="T_bd3b5_level0_row3" class="row_heading level0 row3" >SHAP</th>
#       <td id="T_bd3b5_row3_col0" class="data row3 col0" >0.041938</td>
#       <td id="T_bd3b5_row3_col1" class="data row3 col1" >-0.097407</td>
#       <td id="T_bd3b5_row3_col2" class="data row3 col2" >-0.067262</td>
#       <td id="T_bd3b5_row3_col3" class="data row3 col3" >0.793392</td>
#       <td id="T_bd3b5_row3_col4" class="data row3 col4" >0.605110</td>
#       <td id="T_bd3b5_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_bd3b5_row3_col6" class="data row3 col6" >-0.021804</td>
#       <td id="T_bd3b5_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_bd3b5_row3_col8" class="data row3 col8" >0.166667</td>
#       <td id="T_bd3b5_row3_col9" class="data row3 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bd3b5_level0_row4" class="row_heading level0 row4" >LIME</th>
#       <td id="T_bd3b5_row4_col0" class="data row4 col0" >0.191277</td>
#       <td id="T_bd3b5_row4_col1" class="data row4 col1" >-0.070717</td>
#       <td id="T_bd3b5_row4_col2" class="data row4 col2" >0.269628</td>
#       <td id="T_bd3b5_row4_col3" class="

# %% [markdown]
# ## Percentage (positive)

# %%
thresholds = np.arange(0, 1.1, 0.1)
df_eval, style_df = evalt.evaluate_explainers(text, explanations, thresholds, based_on = "perc", only_pos = False, style_df=True)
style_df
# Out:
# <style type="text/css">
# #T_04e36_row0_col0, #T_04e36_row0_col1 {
#   background-color: #efd4d6;
#   color: #000000;
# }
# #T_04e36_row0_col2 {
#   background-color: #efdbdd;
#   color: #000000;
# }
# #T_04e36_row0_col3, #T_04e36_row2_col1 {
#   background-color: #eab3b7;
#   color: #000000;
# }
# #T_04e36_row0_col4 {
#   background-color: #e59097;
#   color: #f1f1f1;
#   background-color: #bfabec;
#   color: #000000;
# }
# #T_04e36_row0_col5, #T_04e36_row0_col7, #T_04e36_row2_col9 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #cee5ec;
#   color: #000000;
# }
# #T_04e36_row0_col6, #T_04e36_row4_col6 {
#   background-color: #eff0f2;
#   color: #000000;
#   background-color: #7777f9;
#   color: #f1f1f1;
# }
# #T_04e36_row0_col8, #T_04e36_row3_col8 {
#   background-color: #eed3d5;
#   color: #000000;
#   background-color: #8c8cf8;
#   color: #f1f1f1;
# }
# #T_04e36_row0_col9, #T_04e36_row3_col5, #T_04e36_row3_col7, #T_04e36_row3_col9 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #add8e6;
#   color: #000000;
# }
# #T_04e36_row1_col0 {
#   background-color: #cedae4;
#   color: #000000;
# }
# #T_04e36_row1_col1, #T_04e36_row2_col0 {
#   background-color: #ebb9bd;
#   color: #000000;
# }
# #T_04e36_row1_col2 {
#   background-color: #e8ecef;
#   color: #000000;
# }
# #T_04e36_row1_col3, #T_04e36_row2_col3 {
#   background-color: #c2d2df;
#   color: #000000;
# }
# #T_04e36_row1_col4 {
#   background-color: #edeff1;
#   color: #000000;
#   background-color: #e9f1ed;
#   color: #000000;
# }
# #T_04e36_row1_col5, #T_04e36_row1_col7 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #eff1f2;
#   color: #000000;
# }
# #T_04e36_row1_col6 {
#   background-color: #e2757d;
#   color: #f1f1f1;
#   background-color: #cacaf5;
#   color: #000000;
# }
# #T_04e36_row1_col8 {
#   background-color: #de5963;
#   color: #f1f1f1;
#   background-color: #ddddf4;
#   color: #000000;
# }
# #T_04e36_row1_col9, #T_04e36_row2_col5, #T_04e36_row2_col7 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #dfebef;
#   color: #000000;
# }
# #T_04e36_row2_col2 {
#   background-color: #f0e3e3;
#   color: #000000;
# }
# #T_04e36_row2_col4 {
#   background-color: #f1f1f2;
#   color: #000000;
#   background-color: #eff2f0;
#   color: #000000;
# }
# #T_04e36_row2_col6 {
#   background-color: #e37e85;
#   color: #f1f1f1;
#   background-color: #c4c4f5;
#   color: #000000;
# }
# #T_04e36_row2_col8 {
#   background-color: #e2777f;
#   color: #f1f1f1;
#   background-color: #c9c9f5;
#   color: #000000;
# }
# #T_04e36_row3_col0 {
#   background-color: #f1eaea;
#   color: #000000;
# }
# #T_04e36_row3_col1 {
#   background-color: #e0e6eb;
#   color: #000000;
# }
# #T_04e36_row3_col2 {
#   background-color: #e5eaee;
#   color: #000000;
# }
# #T_04e36_row3_col3 {
#   background-color: #df6069;
#   color: #f1f1f1;
# }
# #T_04e36_row3_col4 {
#   background-color: #e37b83;
#   color: #f1f1f1;
#   background-color: #b49cea;
#   color: #f1f1f1;
# }
# #T_04e36_row3_col6 {
#   background-color: #edeff1;
#   color: #000000;
#   background-color: #7676f9;
#   color: #f1f1f1;
# }
# #T_04e36_row4_col0 {
#   background-color: #eecfd1;
#   color: #000000;
# }
# #T_04e36_row4_col1 {
#   background-color: #e4e9ed;
#   color: #000000;
# }
# #T_04e36_row4_col2 {
#   background-color: #ecc0c3;
#   color: #000000;
# }
# #T_04e36_row4_col3 {
#   background-color: #ebbcbf;
#   color: #000000;
# }
# #T_04e36_row4_col4 {
#   background-color: #e4858c;
#   color: #f1f1f1;
#   background-color: #b9a3eb;
#   color: #000000;
# }
# #T_04e36_row4_col5, #T_04e36_row4_col7, #T_04e36_row4_col9 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #bedee9;
#   color: #000000;
# }
# #T_04e36_row4_col8 {
#   background-color: #eab5b9;
#   color: #000000;
#   background-color: #a0a0f7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_04e36">
#   <thead>
#     <tr>
#       <th class="index_name level0" >tokens</th>
#       <th id="T_04e36_level0_col0" class="col_heading level0 col0" >You</th>
#       <th id="T_04e36_level0_col1" class="col_heading level0 col1" >are</th>
#       <th id="T_04e36_level0_col2" class="col_heading level0 col2" >a</th>
#       <th id="T_04e36_level0_col3" class="col_heading level0 col3" >woman</th>
#       <th id="T_04e36_level0_col4" class="col_heading level0 col4" >aopc_compr</th>
#       <th id="T_04e36_level0_col5" class="col_heading level0 col5" >aopc_compr_r</th>
#       <th id="T_04e36_level0_col6" class="col_heading level0 col6" >aopc_suff</th>
#       <th id="T_04e36_level0_col7" class="col_heading level0 col7" >aopc_suff_r</th>
#       <th id="T_04e36_level0_col8" class="col_heading level0 col8" >taud_loo</th>
#       <th id="T_04e36_level0_col9" class="col_heading level0 col9" >taud_loo_r</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04e36_level0_row0" class="row_heading level0 row0" >G</th>
#       <td id="T_04e36_row0_col0" class="data row0 col0" >0.159478</td>
#       <td id="T_04e36_row0_col1" class="data row0 col1" >0.163659</td>
#       <td id="T_04e36_row0_col2" class="data row0 col2" >0.117216</td>
#       <td id="T_04e36_row0_col3" class="data row0 col3" >0.341822</td>
#       <td id="T_04e36_row0_col4" class="data row0 col4" >0.528060</td>
#       <td id="T_04e36_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_04e36_row0_col6" class="data row0 col6" >-0.008643</td>
#       <td id="T_04e36_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_04e36_row0_col8" class="data row0 col8" >0.166667</td>
#       <td id="T_04e36_row0_col9" class="data row0 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_04e36_level0_row1" class="row_heading level0 row1" >GxI</th>
#       <td id="T_04e36_row1_col0" class="data row1 col0" >-0.201490</td>
#       <td id="T_04e36_row1_col1" class="data row1 col1" >0.308628</td>
#       <td id="T_04e36_row1_col2" class="data row1 col2" >-0.051436</td>
#       <td id="T_04e36_row1_col3" class="data row1 col3" >-0.271019</td>
#       <td id="T_04e36_row1_col4" class="data row1 col4" >-0.021811</td>
#       <td id="T_04e36_row1_col5" class="data row1 col5" >5</td>
#       <td id="T_04e36_row1_col6" class="data row1 col6" >0.678475</td>
#       <td id="T_04e36_row1_col7" class="data row1 col7" >5</td>
#       <td id="T_04e36_row1_col8" class="data row1 col8" >0.833333</td>
#       <td id="T_04e36_row1_col9" class="data row1 col9" >4</td>
#     </tr>
#     <tr>
#       <th id="T_04e36_level0_row2" class="row_heading level0 row2" >IG</th>
#       <td id="T_04e36_row2_col0" class="data row2 col0" >0.306092</td>
#       <td id="T_04e36_row2_col1" class="data row2 col1" >0.341990</td>
#       <td id="T_04e36_row2_col2" class="data row2 col2" >0.082422</td>
#       <td id="T_04e36_row2_col3" class="data row2 col3" >-0.269495</td>
#       <td id="T_04e36_row2_col4" class="data row2 col4" >-0.001479</td>
#       <td id="T_04e36_row2_col5" class="data row2 col5" >4</td>
#       <td id="T_04e36_row2_col6" class="data row2 col6" >0.626123</td>
#       <td id="T_04e36_row2_col7" class="data row2 col7" >4</td>
#       <td id="T_04e36_row2_col8" class="data row2 col8" >0.666667</td>
#       <td id="T_04e36_row2_col9" class="data row2 col9" >3</td>
#     </tr>
#     <tr>
#       <th id="T_04e36_level0_row3" class="row_heading level0 row3" >SHAP</th>
#       <td id="T_04e36_row3_col0" class="data row3 col0" >0.041938</td>
#       <td id="T_04e36_row3_col1" class="data row3 col1" >-0.097407</td>
#       <td id="T_04e36_row3_col2" class="data row3 col2" >-0.067262</td>
#       <td id="T_04e36_row3_col3" class="data row3 col3" >0.793392</td>
#       <td id="T_04e36_row3_col4" class="data row3 col4" >0.645066</td>
#       <td id="T_04e36_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_04e36_row3_col6" class="data row3 col6" >-0.019568</td>
#       <td id="T_04e36_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_04e36_row3_col8" class="data row3 col8" >0.166667</td>
#       <td id="T_04e36_row3_col9" class="data row3 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_04e36_level0_row4" class="row_heading level0 row4" >LIME</th>
#       <td id="T_04e36_row4_col0" class="data row4 col0" >0.191277</td>
#       <td id="T_04e36_row4_col1" class="data row4 col1" >-0.070717</td>
#       <td id="T_04e36_row4_col2" class="data row4 col2" >0.269628</td>
#       <td id="T_04e36_row4_col3" class="

# %% [markdown]
# ## Threshold

# %%
thresholds = [0.05, 0.1, 0.2, 0.3]
df_eval, style_df = evalt.evaluate_explainers(text, explanations, thresholds, based_on = "th")
style_df
# Out:
# <style type="text/css">
# #T_69ae7_row0_col0, #T_69ae7_row0_col1 {
#   background-color: #efd4d6;
#   color: #000000;
# }
# #T_69ae7_row0_col2 {
#   background-color: #efdbdd;
#   color: #000000;
# }
# #T_69ae7_row0_col3, #T_69ae7_row2_col1 {
#   background-color: #eab3b7;
#   color: #000000;
# }
# #T_69ae7_row0_col4 {
#   background-color: #e9a8ad;
#   color: #000000;
#   background-color: #cbbced;
#   color: #000000;
# }
# #T_69ae7_row0_col5, #T_69ae7_row2_col9, #T_69ae7_row4_col7 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #cee5ec;
#   color: #000000;
# }
# #T_69ae7_row0_col6 {
#   background-color: #f1f1f2;
#   color: #000000;
#   background-color: #7878f9;
#   color: #f1f1f1;
# }
# #T_69ae7_row0_col7, #T_69ae7_row4_col5, #T_69ae7_row4_col9 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #bedee9;
#   color: #000000;
# }
# #T_69ae7_row0_col8, #T_69ae7_row3_col8 {
#   background-color: #eed3d5;
#   color: #000000;
#   background-color: #8c8cf8;
#   color: #f1f1f1;
# }
# #T_69ae7_row0_col9, #T_69ae7_row3_col5, #T_69ae7_row3_col7, #T_69ae7_row3_col9 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #add8e6;
#   color: #000000;
# }
# #T_69ae7_row1_col0 {
#   background-color: #cedae4;
#   color: #000000;
# }
# #T_69ae7_row1_col1, #T_69ae7_row2_col0 {
#   background-color: #ebb9bd;
#   color: #000000;
# }
# #T_69ae7_row1_col2 {
#   background-color: #e8ecef;
#   color: #000000;
# }
# #T_69ae7_row1_col3, #T_69ae7_row2_col3 {
#   background-color: #c2d2df;
#   color: #000000;
# }
# #T_69ae7_row1_col4 {
#   background-color: #f1f1f2;
#   color: #000000;
#   background-color: #eff2f0;
#   color: #000000;
# }
# #T_69ae7_row1_col5, #T_69ae7_row1_col7 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #eff1f2;
#   color: #000000;
# }
# #T_69ae7_row1_col6 {
#   background-color: #e17179;
#   color: #f1f1f1;
#   background-color: #cdcdf5;
#   color: #000000;
# }
# #T_69ae7_row1_col8 {
#   background-color: #de5963;
#   color: #f1f1f1;
#   background-color: #ddddf4;
#   color: #000000;
# }
# #T_69ae7_row1_col9, #T_69ae7_row2_col5, #T_69ae7_row2_col7 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #dfebef;
#   color: #000000;
# }
# #T_69ae7_row2_col2 {
#   background-color: #f0e3e3;
#   color: #000000;
# }
# #T_69ae7_row2_col4 {
#   background-color: #f2f1f1;
#   color: #000000;
#   background-color: #f2f1f2;
#   color: #000000;
# }
# #T_69ae7_row2_col6 {
#   background-color: #e58d94;
#   color: #f1f1f1;
#   background-color: #babaf6;
#   color: #000000;
# }
# #T_69ae7_row2_col8 {
#   background-color: #e2777f;
#   color: #f1f1f1;
#   background-color: #c9c9f5;
#   color: #000000;
# }
# #T_69ae7_row3_col0 {
#   background-color: #f1eaea;
#   color: #000000;
# }
# #T_69ae7_row3_col1 {
#   background-color: #e0e6eb;
#   color: #000000;
# }
# #T_69ae7_row3_col2 {
#   background-color: #e5eaee;
#   color: #000000;
# }
# #T_69ae7_row3_col3 {
#   background-color: #df6069;
#   color: #f1f1f1;
# }
# #T_69ae7_row3_col4 {
#   background-color: #e69298;
#   color: #f1f1f1;
#   background-color: #c0acec;
#   color: #000000;
# }
# #T_69ae7_row3_col6 {
#   background-color: #eff0f2;
#   color: #000000;
#   background-color: #7777f9;
#   color: #f1f1f1;
# }
# #T_69ae7_row4_col0 {
#   background-color: #eecfd1;
#   color: #000000;
# }
# #T_69ae7_row4_col1 {
#   background-color: #e4e9ed;
#   color: #000000;
# }
# #T_69ae7_row4_col2 {
#   background-color: #ecc0c3;
#   color: #000000;
# }
# #T_69ae7_row4_col3 {
#   background-color: #ebbcbf;
#   color: #000000;
# }
# #T_69ae7_row4_col4 {
#   background-color: #e6989e;
#   color: #000000;
#   background-color: #c3b1ec;
#   color: #000000;
# }
# #T_69ae7_row4_col6 {
#   background-color: #f1e4e5;
#   color: #000000;
#   background-color: #8181f8;
#   color: #f1f1f1;
# }
# #T_69ae7_row4_col8 {
#   background-color: #eab5b9;
#   color: #000000;
#   background-color: #a0a0f7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_69ae7">
#   <thead>
#     <tr>
#       <th class="index_name level0" >tokens</th>
#       <th id="T_69ae7_level0_col0" class="col_heading level0 col0" >You</th>
#       <th id="T_69ae7_level0_col1" class="col_heading level0 col1" >are</th>
#       <th id="T_69ae7_level0_col2" class="col_heading level0 col2" >a</th>
#       <th id="T_69ae7_level0_col3" class="col_heading level0 col3" >woman</th>
#       <th id="T_69ae7_level0_col4" class="col_heading level0 col4" >aopc_compr</th>
#       <th id="T_69ae7_level0_col5" class="col_heading level0 col5" >aopc_compr_r</th>
#       <th id="T_69ae7_level0_col6" class="col_heading level0 col6" >aopc_suff</th>
#       <th id="T_69ae7_level0_col7" class="col_heading level0 col7" >aopc_suff_r</th>
#       <th id="T_69ae7_level0_col8" class="col_heading level0 col8" >taud_loo</th>
#       <th id="T_69ae7_level0_col9" class="col_heading level0 col9" >taud_loo_r</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69ae7_level0_row0" class="row_heading level0 row0" >G</th>
#       <td id="T_69ae7_row0_col0" class="data row0 col0" >0.159478</td>
#       <td id="T_69ae7_row0_col1" class="data row0 col1" >0.163659</td>
#       <td id="T_69ae7_row0_col2" class="data row0 col2" >0.117216</td>
#       <td id="T_69ae7_row0_col3" class="data row0 col3" >0.341822</td>
#       <td id="T_69ae7_row0_col4" class="data row0 col4" >0.403235</td>
#       <td id="T_69ae7_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_69ae7_row0_col6" class="data row0 col6" >-0.006918</td>
#       <td id="T_69ae7_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_69ae7_row0_col8" class="data row0 col8" >0.166667</td>
#       <td id="T_69ae7_row0_col9" class="data row0 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_69ae7_level0_row1" class="row_heading level0 row1" >GxI</th>
#       <td id="T_69ae7_row1_col0" class="data row1 col0" >-0.201490</td>
#       <td id="T_69ae7_row1_col1" class="data row1 col1" >0.308628</td>
#       <td id="T_69ae7_row1_col2" class="data row1 col2" >-0.051436</td>
#       <td id="T_69ae7_row1_col3" class="data row1 col3" >-0.271019</td>
#       <td id="T_69ae7_row1_col4" class="data row1 col4" >-0.002818</td>
#       <td id="T_69ae7_row1_col5" class="data row1 col5" >5</td>
#       <td id="T_69ae7_row1_col6" class="data row1 col6" >0.701342</td>
#       <td id="T_69ae7_row1_col7" class="data row1 col7" >5</td>
#       <td id="T_69ae7_row1_col8" class="data row1 col8" >0.833333</td>
#       <td id="T_69ae7_row1_col9" class="data row1 col9" >4</td>
#     </tr>
#     <tr>
#       <th id="T_69ae7_level0_row2" class="row_heading level0 row2" >IG</th>
#       <td id="T_69ae7_row2_col0" class="data row2 col0" >0.306092</td>
#       <td id="T_69ae7_row2_col1" class="data row2 col1" >0.341990</td>
#       <td id="T_69ae7_row2_col2" class="data row2 col2" >0.082422</td>
#       <td id="T_69ae7_row2_col3" class="data row2 col3" >-0.269495</td>
#       <td id="T_69ae7_row2_col4" class="data row2 col4" >0.002280</td>
#       <td id="T_69ae7_row2_col5" class="data row2 col5" >4</td>
#       <td id="T_69ae7_row2_col6" class="data row2 col6" >0.546013</td>
#       <td id="T_69ae7_row2_col7" class="data row2 col7" >4</td>
#       <td id="T_69ae7_row2_col8" class="data row2 col8" >0.666667</td>
#       <td id="T_69ae7_row2_col9" class="data row2 col9" >3</td>
#     </tr>
#     <tr>
#       <th id="T_69ae7_level0_row3" class="row_heading level0 row3" >SHAP</th>
#       <td id="T_69ae7_row3_col0" class="data row3 col0" >0.041938</td>
#       <td id="T_69ae7_row3_col1" class="data row3 col1" >-0.097407</td>
#       <td id="T_69ae7_row3_col2" class="data row3 col2" >-0.067262</td>
#       <td id="T_69ae7_row3_col3" class="data row3 col3" >0.793392</td>
#       <td id="T_69ae7_row3_col4" class="data row3 col4" >0.517883</td>
#       <td id="T_69ae7_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_69ae7_row3_col6" class="data row3 col6" >-0.013836</td>
#       <td id="T_69ae7_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_69ae7_row3_col8" class="data row3 col8" >0.166667</td>
#       <td id="T_69ae7_row3_col9" class="data row3 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_69ae7_level0_row4" class="row_heading level0 row4" >LIME</th>
#       <td id="T_69ae7_row4_col0" class="data row4 col0" >0.191277</td>
#       <td id="T_69ae7_row4_col1" class="data row4 col1" >-0.070717</td>
#       <td id="T

# %% [markdown]
# ## Top k

# %%
thresholds = [1,2,3,4]
df_eval, style_df = evalt.evaluate_explainers(text, explanations, thresholds, based_on = "k", only_pos = False, style_df=True)
style_df
# Out:
# <style type="text/css">
# #T_800fe_row0_col0, #T_800fe_row0_col1 {
#   background-color: #efd4d6;
#   color: #000000;
# }
# #T_800fe_row0_col2 {
#   background-color: #efdbdd;
#   color: #000000;
# }
# #T_800fe_row0_col3, #T_800fe_row2_col1 {
#   background-color: #eab3b7;
#   color: #000000;
# }
# #T_800fe_row0_col4 {
#   background-color: #e79ba1;
#   color: #000000;
#   background-color: #c5b3ec;
#   color: #000000;
# }
# #T_800fe_row0_col5, #T_800fe_row0_col7, #T_800fe_row2_col9 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #cee5ec;
#   color: #000000;
# }
# #T_800fe_row0_col6 {
#   background-color: #f1f1f2;
#   color: #000000;
#   background-color: #7878f9;
#   color: #f1f1f1;
# }
# #T_800fe_row0_col8, #T_800fe_row3_col8 {
#   background-color: #eed3d5;
#   color: #000000;
#   background-color: #8c8cf8;
#   color: #f1f1f1;
# }
# #T_800fe_row0_col9, #T_800fe_row3_col5, #T_800fe_row3_col7, #T_800fe_row3_col9 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #add8e6;
#   color: #000000;
# }
# #T_800fe_row1_col0 {
#   background-color: #cedae4;
#   color: #000000;
# }
# #T_800fe_row1_col1, #T_800fe_row2_col0 {
#   background-color: #ebb9bd;
#   color: #000000;
# }
# #T_800fe_row1_col2 {
#   background-color: #e8ecef;
#   color: #000000;
# }
# #T_800fe_row1_col3, #T_800fe_row2_col3 {
#   background-color: #c2d2df;
#   color: #000000;
# }
# #T_800fe_row1_col4 {
#   background-color: #f1e7e7;
#   color: #000000;
#   background-color: #eceaf2;
#   color: #000000;
# }
# #T_800fe_row1_col5, #T_800fe_row1_col7 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #eff1f2;
#   color: #000000;
# }
# #T_800fe_row1_col6 {
#   background-color: #e69399;
#   color: #f1f1f1;
#   background-color: #b6b6f6;
#   color: #000000;
# }
# #T_800fe_row1_col8 {
#   background-color: #de5963;
#   color: #f1f1f1;
#   background-color: #ddddf4;
#   color: #000000;
# }
# #T_800fe_row1_col9, #T_800fe_row2_col5, #T_800fe_row2_col7 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #dfebef;
#   color: #000000;
# }
# #T_800fe_row2_col2 {
#   background-color: #f0e3e3;
#   color: #000000;
# }
# #T_800fe_row2_col4 {
#   background-color: #f1e5e6;
#   color: #000000;
#   background-color: #ebe9f2;
#   color: #000000;
# }
# #T_800fe_row2_col6 {
#   background-color: #e79ba1;
#   color: #000000;
#   background-color: #b1b1f6;
#   color: #000000;
# }
# #T_800fe_row2_col8 {
#   background-color: #e2777f;
#   color: #f1f1f1;
#   background-color: #c9c9f5;
#   color: #000000;
# }
# #T_800fe_row3_col0 {
#   background-color: #f1eaea;
#   color: #000000;
# }
# #T_800fe_row3_col1 {
#   background-color: #e0e6eb;
#   color: #000000;
# }
# #T_800fe_row3_col2 {
#   background-color: #e5eaee;
#   color: #000000;
# }
# #T_800fe_row3_col3 {
#   background-color: #df6069;
#   color: #f1f1f1;
# }
# #T_800fe_row3_col4 {
#   background-color: #e58c93;
#   color: #f1f1f1;
#   background-color: #bda8eb;
#   color: #000000;
# }
# #T_800fe_row3_col6, #T_800fe_row4_col6 {
#   background-color: #eff0f2;
#   color: #000000;
#   background-color: #7777f9;
#   color: #f1f1f1;
# }
# #T_800fe_row4_col0 {
#   background-color: #eecfd1;
#   color: #000000;
# }
# #T_800fe_row4_col1 {
#   background-color: #e4e9ed;
#   color: #000000;
# }
# #T_800fe_row4_col2 {
#   background-color: #ecc0c3;
#   color: #000000;
# }
# #T_800fe_row4_col3 {
#   background-color: #ebbcbf;
#   color: #000000;
# }
# #T_800fe_row4_col4 {
#   background-color: #e69298;
#   color: #f1f1f1;
#   background-color: #c0acec;
#   color: #000000;
# }
# #T_800fe_row4_col5, #T_800fe_row4_col7, #T_800fe_row4_col9 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #bedee9;
#   color: #000000;
# }
# #T_800fe_row4_col8 {
#   background-color: #eab5b9;
#   color: #000000;
#   background-color: #a0a0f7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_800fe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >tokens</th>
#       <th id="T_800fe_level0_col0" class="col_heading level0 col0" >You</th>
#       <th id="T_800fe_level0_col1" class="col_heading level0 col1" >are</th>
#       <th id="T_800fe_level0_col2" class="col_heading level0 col2" >a</th>
#       <th id="T_800fe_level0_col3" class="col_heading level0 col3" >woman</th>
#       <th id="T_800fe_level0_col4" class="col_heading level0 col4" >aopc_compr</th>
#       <th id="T_800fe_level0_col5" class="col_heading level0 col5" >aopc_compr_r</th>
#       <th id="T_800fe_level0_col6" class="col_heading level0 col6" >aopc_suff</th>
#       <th id="T_800fe_level0_col7" class="col_heading level0 col7" >aopc_suff_r</th>
#       <th id="T_800fe_level0_col8" class="col_heading level0 col8" >taud_loo</th>
#       <th id="T_800fe_level0_col9" class="col_heading level0 col9" >taud_loo_r</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_800fe_level0_row0" class="row_heading level0 row0" >G</th>
#       <td id="T_800fe_row0_col0" class="data row0 col0" >0.159478</td>
#       <td id="T_800fe_row0_col1" class="data row0 col1" >0.163659</td>
#       <td id="T_800fe_row0_col2" class="data row0 col2" >0.117216</td>
#       <td id="T_800fe_row0_col3" class="data row0 col3" >0.341822</td>
#       <td id="T_800fe_row0_col4" class="data row0 col4" >0.472835</td>
#       <td id="T_800fe_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_800fe_row0_col6" class="data row0 col6" >-0.005580</td>
#       <td id="T_800fe_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_800fe_row0_col8" class="data row0 col8" >0.166667</td>
#       <td id="T_800fe_row0_col9" class="data row0 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_800fe_level0_row1" class="row_heading level0 row1" >GxI</th>
#       <td id="T_800fe_row1_col0" class="data row1 col0" >-0.201490</td>
#       <td id="T_800fe_row1_col1" class="data row1 col1" >0.308628</td>
#       <td id="T_800fe_row1_col2" class="data row1 col2" >-0.051436</td>
#       <td id="T_800fe_row1_col3" class="data row1 col3" >-0.271019</td>
#       <td id="T_800fe_row1_col4" class="data row1 col4" >0.058035</td>
#       <td id="T_800fe_row1_col5" class="data row1 col5" >5</td>
#       <td id="T_800fe_row1_col6" class="data row1 col6" >0.508075</td>
#       <td id="T_800fe_row1_col7" class="data row1 col7" >5</td>
#       <td id="T_800fe_row1_col8" class="data row1 col8" >0.833333</td>
#       <td id="T_800fe_row1_col9" class="data row1 col9" >4</td>
#     </tr>
#     <tr>
#       <th id="T_800fe_level0_row2" class="row_heading level0 row2" >IG</th>
#       <td id="T_800fe_row2_col0" class="data row2 col0" >0.306092</td>
#       <td id="T_800fe_row2_col1" class="data row2 col1" >0.341990</td>
#       <td id="T_800fe_row2_col2" class="data row2 col2" >0.082422</td>
#       <td id="T_800fe_row2_col3" class="data row2 col3" >-0.269495</td>
#       <td id="T_800fe_row2_col4" class="data row2 col4" >0.069896</td>
#       <td id="T_800fe_row2_col5" class="data row2 col5" >4</td>
#       <td id="T_800fe_row2_col6" class="data row2 col6" >0.470725</td>
#       <td id="T_800fe_row2_col7" class="data row2 col7" >4</td>
#       <td id="T_800fe_row2_col8" class="data row2 col8" >0.666667</td>
#       <td id="T_800fe_row2_col9" class="data row2 col9" >3</td>
#     </tr>
#     <tr>
#       <th id="T_800fe_level0_row3" class="row_heading level0 row3" >SHAP</th>
#       <td id="T_800fe_row3_col0" class="data row3 col0" >0.041938</td>
#       <td id="T_800fe_row3_col1" class="data row3 col1" >-0.097407</td>
#       <td id="T_800fe_row3_col2" class="data row3 col2" >-0.067262</td>
#       <td id="T_800fe_row3_col3" class="data row3 col3" >0.793392</td>
#       <td id="T_800fe_row3_col4" class="data row3 col4" >0.550037</td>
#       <td id="T_800fe_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_800fe_row3_col6" class="data row3 col6" >-0.012360</td>
#       <td id="T_800fe_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_800fe_row3_col8" class="data row3 col8" >0.166667</td>
#       <td id="T_800fe_row3_col9" class="data row3 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_800fe_level0_row4" class="row_heading level0 row4" >LIME</th>
#       <td id="T_800fe_row4_col0" class="data row4 col0" >0.191277</td>
#       <td id="T_800fe_row4_col1" class="data row4 col1" >-0.070717</td>
#       <td id="T_800fe_row4_col2" class="data row4 col2" >0.269628</td>
#       <td id="T_800fe_row4_col3" class="da

# %% [markdown]
# # Plausibility

# %%
text = "I am a woman"
exp.classify(text)
print(f"Importance occlusion:\n {exp.compute_occlusion_importance(text).numpy()}")
explanations =  exp.compute_table(text, target = 1)

from nlxplain import Evalutator

evalt = Evalutator(exp)


true_explanation = [0,1,0,1]
thresholds = np.arange(0, 1.1, 0.1)
df_eval, style_df = evalt.evaluate_explainers(text, explanations, thresholds, true_rationale=true_explanation, \
                                target=1, based_on = "perc", style_df=True)
style_df
# Out:
# IDX: I am a woman
# Text: I am a woman
# Probabilities: tensor([[0.2111, 0.7889]])
# Prediction: 1
# Importance occlusion:
#  [-0.00160569  0.00908154  0.00839043 -0.66411984]
# <style type="text/css">
# #T_5b980_row0_col0 {
#   background-color: #efdadb;
#   color: #000000;
# }
# #T_5b980_row0_col1 {
#   background-color: #efd4d6;
#   color: #000000;
# }
# #T_5b980_row0_col2, #T_5b980_row4_col0 {
#   background-color: #efdbdd;
#   color: #000000;
# }
# #T_5b980_row0_col3, #T_5b980_row4_col3 {
#   background-color: #eab0b5;
#   color: #000000;
# }
# #T_5b980_row0_col4 {
#   background-color: #e4868d;
#   color: #f1f1f1;
#   background-color: #baa4eb;
#   color: #000000;
# }
# #T_5b980_row0_col5, #T_5b980_row1_col9, #T_5b980_row2_col7, #T_5b980_row4_col11 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #dfebef;
#   color: #000000;
# }
# #T_5b980_row0_col6, #T_5b980_row4_col6 {
#   background-color: #edeff1;
#   color: #000000;
#   background-color: #7676f9;
#   color: #f1f1f1;
# }
# #T_5b980_row0_col7, #T_5b980_row0_col9, #T_5b980_row1_col11, #T_5b980_row3_col5 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #cee5ec;
#   color: #000000;
# }
# #T_5b980_row0_col8 {
#   background-color: #eab5b9;
#   color: #000000;
#   background-color: #a0a0f7;
#   color: #f1f1f1;
# }
# #T_5b980_row0_col10 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #936ee6;
#   color: #f1f1f1;
# }
# #T_5b980_row0_col11, #T_5b980_row1_col5, #T_5b980_row3_col7, #T_5b980_row3_col9 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #add8e6;
#   color: #000000;
# }
# #T_5b980_row1_col0 {
#   background-color: #aec5d6;
#   color: #000000;
# }
# #T_5b980_row1_col1 {
#   background-color: #c8d7e1;
#   color: #000000;
# }
# #T_5b980_row1_col2 {
#   background-color: #d9e2e9;
#   color: #000000;
# }
# #T_5b980_row1_col3 {
#   background-color: #d6e0e7;
#   color: #000000;
# }
# #T_5b980_row1_col4, #T_5b980_row1_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #000000;
#   color: #f1f1f1;
#   color: black;
#   background-color: white;
# }
# #T_5b980_row1_col7, #T_5b980_row2_col5, #T_5b980_row2_col9, #T_5b980_row2_col11 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #eff1f2;
#   color: #000000;
# }
# #T_5b980_row1_col8 {
#   background-color: #e6959b;
#   color: #f1f1f1;
#   background-color: #b5b5f6;
#   color: #000000;
# }
# #T_5b980_row1_col10 {
#   background-color: #e06770;
#   color: #f1f1f1;
#   background-color: #aa8de9;
#   color: #f1f1f1;
# }
# #T_5b980_row2_col0 {
#   background-color: #e8a5aa;
#   color: #000000;
# }
# #T_5b980_row2_col1 {
#   background-color: #ecc5c7;
#   color: #000000;
# }
# #T_5b980_row2_col2 {
#   background-color: #f0e3e3;
#   color: #000000;
# }
# #T_5b980_row2_col3 {
#   background-color: #c3d3df;
#   color: #000000;
# }
# #T_5b980_row2_col4 {
#   background-color: #f1f1f2;
#   color: #000000;
#   background-color: #eff2f0;
#   color: #000000;
# }
# #T_5b980_row2_col6 {
#   background-color: #e2747c;
#   color: #f1f1f1;
#   background-color: #cbcbf5;
#   color: #000000;
# }
# #T_5b980_row2_col8 {
#   background-color: #e2777f;
#   color: #f1f1f1;
#   background-color: #c9c9f5;
#   color: #000000;
# }
# #T_5b980_row2_col10 {
#   background-color: #eab5b9;
#   color: #000000;
#   background-color: #d2c6ee;
#   color: #000000;
# }
# #T_5b980_row3_col0 {
#   background-color: #ebeef0;
#   color: #000000;
# }
# #T_5b980_row3_col1 {
#   background-color: #d8e1e8;
#   color: #000000;
# }
# #T_5b980_row3_col2 {
#   background-color: #e9edf0;
#   color: #000000;
# }
# #T_5b980_row3_col3 {
#   background-color: #df636c;
#   color: #f1f1f1;
# }
# #T_5b980_row3_col4 {
#   background-color: #e2777f;
#   color: #f1f1f1;
#   background-color: #b299ea;
#   color: #f1f1f1;
# }
# #T_5b980_row3_col6 {
#   background-color: #eceef1;
#   color: #000000;
#   background-color: #7575f9;
#   color: #f1f1f1;
# }
# #T_5b980_row3_col8 {
#   background-color: #f2f1f1;
#   color: #000000;
#   background-color: #7979f9;
#   color: #f1f1f1;
# }
# #T_5b980_row3_col10 {
#   background-color: #dd505a;
#   color: #f1f1f1;
#   background-color: #9e7de7;
#   color: #f1f1f1;
# }
# #T_5b980_row3_col11, #T_5b980_row4_col5, #T_5b980_row4_col7, #T_5b980_row4_col9 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #bedee9;
#   color: #000000;
# }
# #T_5b980_row4_col1 {
#   background-color: #f2efef;
#   color: #000000;
# }
# #T_5b980_row4_col2 {
#   background-color: #edc9cb;
#   color: #000000;
# }
# #T_5b980_row4_col4 {
#   background-color: #e17179;
#   color: #f1f1f1;
#   background-color: #af95e9;
#   color: #f1f1f1;
# }
# #T_5b980_row4_col8 {
#   background-color: #eed3d5;
#   color: #000000;
#   background-color: #8c8cf8;
#   color: #f1f1f1;
# }
# #T_5b980_row4_col10 {
#   background-color: #e16f78;
#   color: #f1f1f1;
#   background-color: #ae94e9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5b980">
#   <thead>
#     <tr>
#       <th class="index_name level0" >tokens</th>
#       <th id="T_5b980_level0_col0" class="col_heading level0 col0" >I</th>
#       <th id="T_5b980_level0_col1" class="col_heading level0 col1" >am</th>
#       <th id="T_5b980_level0_col2" class="col_heading level0 col2" >a</th>
#       <th id="T_5b980_level0_col3" class="col_heading level0 col3" >woman</th>
#       <th id="T_5b980_level0_col4" class="col_heading level0 col4" >aopc_compr</th>
#       <th id="T_5b980_level0_col5" class="col_heading level0 col5" >aopc_compr_r</th>
#       <th id="T_5b980_level0_col6" class="col_heading level0 col6" >aopc_suff</th>
#       <th id="T_5b980_level0_col7" class="col_heading level0 col7" >aopc_suff_r</th>
#       <th id="T_5b980_level0_col8" class="col_heading level0 col8" >taud_loo</th>
#       <th id="T_5b980_level0_col9" class="col_heading level0 col9" >taud_loo_r</th>
#       <th id="T_5b980_level0_col10" class="col_heading level0 col10" >auprc_plau</th>
#       <th id="T_5b980_level0_col11" class="col_heading level0 col11" >auprc_plau_r</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b980_level0_row0" class="row_heading level0 row0" >G</th>
#       <td id="T_5b980_row0_col0" class="data row0 col0" >0.128154</td>
#       <td id="T_5b980_row0_col1" class="data row0 col1" >0.156558</td>
#       <td id="T_5b980_row0_col2" class="data row0 col2" >0.122124</td>
#       <td id="T_5b980_row0_col3" class="data row0 col3" >0.358661</td>
#       <td id="T_5b980_row0_col4" class="data row0 col4" >0.578760</td>
#       <td id="T_5b980_row0_col5" class="data row0 col5" >4</td>
#       <td id="T_5b980_row0_col6" class="data row0 col6" >-0.015799</td>
#       <td id="T_5b980_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_5b980_row0_col8" class="data row0 col8" >0.333333</td>
#       <td id="T_5b980_row0_col9" class="data row0 col9" >3</td>
#       <td id="T_5b980_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_5b980_row0_col11" class="data row0 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5b980_level0_row1" class="row_heading level0 row1" >GxI</th>
#       <td id="T_5b980_row1_col0" class="data row1 col0" >-0.377682</td>
#       <td id="T_5b980_row1_col1" class="data row1 col1" >-0.230217</td>
#       <td id="T_5b980_row1_col2" class="data row1 col2" >-0.133846</td>
#       <td id="T_5b980_row1_col3" class="data row1 col3" >-0.153122</td>
#       <td id="T_5b980_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_5b980_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_5b980_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_5b980_row1_col7" class="data row1 col7" >5</td>
#       <td id="T_5b980_row1_col8" class="data row1 col8" >0.500000</td>
#       <td id="T_5b980_row1_col9" class="data row1 col9" >4</td>
#       <td id="T_5b980_row1_col10" class="data row1 col10" >0.750000</td>
#       <td id="T_5b980_row1_col11" class="data row1 col11" >3</td>
#     </tr>
#     <tr>
#       <th id="T_5b980_level0_row2" class="row_heading level0 row2" >IG</th>
#       <td id="T_5b980_row2_col0" class="data row2 col0" >0.416557</td>
#       <td id="T_5b980_row2_col1" class="data row2 col1" >0.246852</td>
#       <td id="T_5b980_row2_col2" class="data row2 col2" >0.078772</td>
#       <td id="T_5b980_row2_col3" class="data row2 col3" >-0.257818</td>
#       <td id="T_5b980_row2_col4" class="data row2 col4" >-0.007678</td>
#       <td id="T_5b980_row2_col5" class="data row2 col5" >5</td>
#       <td id="T_5b980_row2_col6" class="data row2 col6" >0.680875</td>
#       <td id="T_5b980_row2_col7" class="data row2 col7" >4</td

# %% [markdown]
# # HateXplain

# %%
from datasets import load_dataset

dataset = load_dataset("hatexplain")
# Out:
# Reusing dataset hatexplain (/Users/eliana/.cache/huggingface/datasets/hatexplain/plain_text/1.0.0/df474d8d8667d89ef30649bf66e9c856ad8305bef4bc147e8e31cbdf1b8e0249)
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 811.02it/s]

# %%
dataset["train"][1].keys()
# Out:
# dict_keys(['id', 'annotators', 'rationales', 'post_tokens'])

# %% [markdown]
# ## Model for hate speech

# %%
#MODEL = f"cardiffnlp/twitter-roberta-base-hate"

#tokenizer_hate = AutoTokenizer.from_pretrained(MODEL)


# PT
#model_hate = AutoModelForSequenceClassification.from_pretrained(MODEL)
#model.save_pretrained(MODEL)

# %%
#exp_hate = Explainer(model_hate, tokenizer_hate)

# %% [markdown]
# ## Evaluate explanations

# %%
from nlxplain import Explainer

# %%
exp = Explainer(model, tokenizer)

# %%
i = 0
instance_hatexplain = dataset["train"][i]
text = " ".join(instance_hatexplain["post_tokens"])

exp.classify(text)
target = exp.get_predicted_label(text)


print(f"Importance occlusion:\n {exp.compute_occlusion_importance(text).numpy()}")
explanations =  exp.compute_table(text, target = target)
# Out:
# IDX: u really think i would not have been raped by feral hindu or muslim back in india or bangladesh and a neo nazi would rape me as well just to see me cry
# Text: u really think i would not have been raped by feral hindu or muslim back in india or bangladesh and a neo nazi would rape me as well just to see me cry
# Probabilities: tensor([[0.5420, 0.4580]])
# Prediction: 0
# Importance occlusion:
#  [-0.07536277  0.00406748 -0.05482131 -0.11015677 -0.03581223  0.01808208
#   0.00583032  0.01801482 -0.0319446  -0.00952613 -0.0555388  -0.01674065
#   0.03008634  0.01789537 -0.00721917  0.0029231   0.00133276 -0.01736441
#   0.00839406  0.00839406  0.01580939  0.01730666  0.01290727  0.02179924
#   0.01306814  0.01662275 -0.00572476  0.0292125   0.00801119 -0.00659114
#  -0.00990164 -0.01178586  0.01762742  0.02804026  0.00994155 -0.00234556
#   0.01261893  0.00761637 -0.00626582  0.01048899]
# Partition explainer: 2it [00:12, 12.64s/it]

# %%
i = 0
instance_hatexplain = dataset["train"][i]
text = " ".join(instance_hatexplain["post_tokens"])

from nlxplain import Evalutator

evalt = Evalutator(exp)

thresholds = np.arange(0, 1.1, 0.1)


# As in hateXplain, we consider the union of explanations
rationales = instance_hatexplain["rationales"]
rationale = [any(each) for each in zip(*rationales)]
rationale = [int(each) for each in rationale]

token_rationale = evalt.get_true_rational_tokens(instance_hatexplain["post_tokens"],\
                                           rationale)
df_eval, style_df = evalt.evaluate_explainers(text, explanations, thresholds, \
                                              true_rationale=token_rationale, target=target, based_on = "perc", style_df=True)
style_df
# Out:
# 40
# <style type="text/css">
# #T_42643_row0_col0, #T_42643_row2_col32, #T_42643_row2_col35, #T_42643_row2_col38 {
#   background-color: #f1e5e6;
#   color: #000000;
# }
# #T_42643_row0_col1, #T_42643_row0_col2, #T_42643_row0_col11, #T_42643_row0_col20, #T_42643_row0_col22, #T_42643_row0_col23, #T_42643_row0_col32, #T_42643_row0_col38, #T_42643_row0_col39, #T_42643_row1_col29, #T_42643_row2_col0, #T_42643_row2_col1, #T_42643_row2_col13, #T_42643_row2_col15, #T_42643_row2_col21, #T_42643_row2_col28, #T_42643_row3_col14, #T_42643_row3_col15, #T_42643_row3_col16, #T_42643_row3_col34, #T_42643_row3_col35, #T_42643_row3_col36, #T_42643_row3_col37, #T_42643_row4_col9, #T_42643_row4_col18 {
#   background-color: #f2eded;
#   color: #000000;
# }
# #T_42643_row0_col3, #T_42643_row2_col33, #T_42643_row4_col5 {
#   background-color: #f1e8e9;
#   color: #000000;
# }
# #T_42643_row0_col4, #T_42643_row0_col7, #T_42643_row0_col9, #T_42643_row0_col12, #T_42643_row0_col15, #T_42643_row0_col16, #T_42643_row0_col24, #T_42643_row0_col25, #T_42643_row0_col28, #T_42643_row0_col30, #T_42643_row1_col14, #T_42643_row1_col17, #T_42643_row2_col9, #T_42643_row2_col11, #T_42643_row2_col18, #T_42643_row2_col22, #T_42643_row2_col30, #T_42643_row3_col4, #T_42643_row3_col5, #T_42643_row3_col6, #T_42643_row3_col19, #T_42643_row3_col20, #T_42643_row3_col21, #T_42643_row3_col32, #T_42643_row4_col34 {
#   background-color: #f2eeee;
#   color: #000000;
# }
# #T_42643_row0_col5, #T_42643_row0_col6, #T_42643_row0_col13, #T_42643_row0_col14, #T_42643_row0_col17, #T_42643_row0_col18, #T_42643_row0_col19, #T_42643_row0_col21, #T_42643_row0_col26, #T_42643_row0_col33, #T_42643_row0_col34, #T_42643_row0_col35, #T_42643_row0_col36, #T_42643_row0_col37, #T_42643_row1_col22, #T_42643_row1_col24, #T_42643_row2_col7, #T_42643_row2_col16, #T_42643_row2_col20, #T_42643_row2_col23, #T_42643_row2_col24, #T_42643_row3_col1, #T_42643_row3_col2, #T_42643_row3_col22, #T_42643_row3_col23, #T_42643_row3_col24, #T_42643_row3_col27, #T_42643_row3_col28, #T_42643_row3_col29, #T_42643_row3_col33, #T_42643_row4_col0, #T_42643_row4_col13, #T_42643_row4_col24, #T_42643_row4_col30 {
#   background-color: #f2efef;
#   color: #000000;
# }
# #T_42643_row0_col8, #T_42643_row2_col26 {
#   background-color: #f1e4e5;
#   color: #000000;
# }
# #T_42643_row0_col10, #T_42643_row0_col27, #T_42643_row0_col29, #T_42643_row1_col3, #T_42643_row1_col23, #T_42643_row2_col34, #T_42643_row2_col39, #T_42643_row3_col26, #T_42643_row4_col6, #T_42643_row4_col20, #T_42643_row4_col23 {
#   background-color: #f2ebeb;
#   color: #000000;
# }
# #T_42643_row0_col31, #T_42643_row1_col4, #T_42643_row2_col17, #T_42643_row2_col19, #T_42643_row2_col36, #T_42643_row3_col3, #T_42643_row3_col11, #T_42643_row3_col12, #T_42643_row3_col13 {
#   background-color: #f1eaea;
#   color: #000000;
# }
# #T_42643_row0_col40 {
#   background-color: #b9ccdb;
#   color: #000000;
#   background-color: #b4d5c6;
#   color: #000000;
# }
# #T_42643_row0_col41, #T_42643_row0_col43, #T_42643_row0_col45, #T_42643_row2_col47 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #eff1f2;
#   color: #000000;
# }
# #T_42643_row0_col42 {
#   background-color: #efd4d6;
#   color: #000000;
#   background-color: #8c8cf8;
#   color: #f1f1f1;
# }
# #T_42643_row0_col44 {
#   background-color: #e38188;
#   color: #f1f1f1;
#   background-color: #c2c2f5;
#   color: #000000;
# }
# #T_42643_row0_col46 {
#   background-color: #e58f95;
#   color: #f1f1f1;
#   background-color: #bfaaeb;
#   color: #000000;
# }
# #T_42643_row0_col47, #T_42643_row2_col43, #T_42643_row4_col41, #T_42643_row4_col45 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #add8e6;
#   color: #000000;
# }
# #T_42643_row1_col0 {
#   background-color: #bfd0dd;
#   color: #000000;
# }
# #T_42643_row1_col1, #T_42643_row1_col7, #T_42643_row4_col31 {
#   background-color: #e9edf0;
#   color: #000000;
# }
# #T_42643_row1_col2, #T_42643_row3_col31 {
#   background-color: #e5eaee;
#   color: #000000;
# }
# #T_42643_row1_col5, #T_42643_row1_col6, #T_42643_row1_col20, #T_42643_row1_col25, #T_42643_row1_col36, #T_42643_row1_col37, #T_42643_row2_col4, #T_42643_row2_col12, #T_42643_row4_col11, #T_42643_row4_col35 {
#   background-color: #eff0f2;
#   color: #000000;
# }
# #T_42643_row1_col8, #T_42643_row1_col13, #T_42643_row1_col15, #T_42643_row1_col16, #T_42643_row1_col18, #T_42643_row1_col21, #T_42643_row1_col34, #T_42643_row1_col35, #T_42643_row1_col39, #T_42643_row2_col2, #T_42643_row2_col8, #T_42643_row2_col10, #T_42643_row2_col14, #T_42643_row2_col31, #T_42643_row3_col7, #T_42643_row3_col9, #T_42643_row4_col26, #T_42643_row4_col29, #T_42643_row4_col32, #T_42643_row4_col33 {
#   background-color: #f1f1f2;
#   color: #000000;
# }
# #T_42643_row1_col9, #T_42643_row1_col11, #T_42643_row1_col19, #T_42643_row1_col28, #T_42643_row1_col31, #T_42643_row2_col3, #T_42643_row2_col5, #T_42643_row2_col6, #T_42643_row2_col27, #T_42643_row2_col29, #T_42643_row3_col17, #T_42643_row3_col18, #T_42643_row3_col25, #T_42643_row3_col38, #T_42643_row3_col39, #T_42643_row4_col15, #T_42643_row4_col38 {
#   background-color: #f2f1f1;
#   color: #000000;
# }
# #T_42643_row1_col10, #T_42643_row1_col26, #T_42643_row1_col38, #T_42643_row3_col30, #T_42643_row4_col1, #T_42643_row4_col8, #T_42643_row4_col19, #T_42643_row4_col25, #T_42643_row4_col27, #T_42643_row4_col28, #T_42643_row4_col36 {
#   background-color: #edeff1;
#   color: #000000;
# }
# #T_42643_row1_col12, #T_42643_row4_col2, #T_42643_row4_col3, #T_42643_row4_col12, #T_42643_row4_col14, #T_42643_row4_col17, #T_42643_row4_col39 {
#   background-color: #ebeef0;
#   color: #000000;
# }
# #T_42643_row1_col27, #T_42643_row1_col30, #T_42643_row1_col32, #T_42643_row1_col33, #T_42643_row4_col7, #T_42643_row4_col10, #T_42643_row4_col16, #T_42643_row4_col21, #T_42643_row4_col22 {
#   background-color: #eceef1;
#   color: #000000;
# }
# #T_42643_row1_col40 {
#   background-color: #d9e2e9;
#   color: #000000;
#   background-color: #d4e6de;
#   color: #000000;
# }
# #T_42643_row1_col41, #T_42643_row1_col43, #T_42643_row1_col45, #T_42643_row4_col47 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #dfebef;
#   color: #000000;
# }
# #T_42643_row1_col42 {
#   background-color: #e0e6eb;
#   color: #000000;
#   background-color: #6c6cf9;
#   color: #f1f1f1;
# }
# #T_42643_row1_col44 {
#   background-color: #e4858c;
#   color: #f1f1f1;
#   background-color: #bfbff5;
#   color: #000000;
# }
# #T_42643_row1_col46 {
#   background-color: #eab6ba;
#   color: #000000;
#   background-color: #d3c7ee;
#   color: #000000;
# }
# #T_42643_row1_col47, #T_42643_row2_col41, #T_42643_row2_col45, #T_42643_row4_col43 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #cee5ec;
#   color: #000000;
# }
# #T_42643_row2_col25, #T_42643_row2_col37 {
#   background-color: #f1e7e7;
#   color: #000000;
# }
# #T_42643_row2_col40 {
#   background-color: #f2efef;
#   color: #000000;
#   background-color: #f0f0f2;
#   color: #000000;
# }
# #T_42643_row2_col42 {
#   background-color: #b1c7d7;
#   color: #000000;
#   background-color: #4c4cfb;
#   color: #f1f1f1;
# }
# #T_42643_row2_col44 {
#   background-color: #e8a1a6;
#   color: #000000;
#   background-color: #adadf6;
#   color: #000000;
# }
# #T_42643_row2_col46 {
#   background-color: #eecfd1;
#   color: #000000;
#   background-color: #dfd8f0;
#   color: #000000;
# }
# #T_42643_row3_col0 {
#   background-color: #e4e9ed;
#   color: #000000;
# }
# #T_42643_row3_col8 {
#   background-color: #e7ebee;
#   color: #000000;
# }
# #T_42643_row3_col10, #T_42643_row4_col4, #T_42643_row4_col37 {
#   background-color: #e8ecef;
#   color: #000000;
# }
# #T_42643_row3_col40 {
#   background-color: #f0e3e3;
#   color: #000000;
#   background-color: #eae7f1;
#   color: #000000;
# }
# #T_42643_row3_col41, #T_42643_row3_col43, #T_42643_row3_col45, #T_42643_row3_col47 {
#   background-color: #da3b46;
#   color: #f1f1f1;
#   background-color: #bedee9;
#   color: #000000;
# }
# #T_42643_row3_col42 {
#   background-color: #b3c8d8;
#   color: #000000;
#   background-color: #4d4dfb;
#   color: #f1f1f1;
# }
# #T_42643_row3_col44 {
#   background-color: #e8a4a9;
#   color: #000000;
#   background-color: #acacf6;
#   color: #000000;
# }
# #T_42643_row3_col46 {
#   background-color: #e9aeb2;
#   color: #000000;
#   background-color: #cec0ee;
#   c
